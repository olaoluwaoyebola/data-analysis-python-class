# %% [markdown]
# # Lesson 1: Introduction to Python Basics

# %% [markdown]
# ## Section 1: Getting started with python & jupyter notebook

# %% [markdown]
# ### Welcome to your first Python for Data Analysis class! This notebook will introduce you to Jupyter Notebook and provide an overview of the basics of Python.

# %%
### - Print statements
### - Comments
